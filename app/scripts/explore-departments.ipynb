# %%
#import packages
import json
from pathlib import Path

# %%
#import data
path = Path("/Users/sromero/Documents/Projects/Jeux/game-colombian-departments/app/src/data/colombian-departments.json")
data = json.loads(path.read_text(encoding="utf-8"))

# %%
data.keys()
# Out:
# dict_keys(['type', 'features'])

# %%
data['features'][0].keys()
# Out:
# dict_keys(['geometry', 'type', 'properties', 'id'])

# %%
data['features'][0]['properties']
# Out:
# {'source': 'https://simplemaps.com',
#  'id': 'CONAR',
#  'name': 'Nariño',
#  'capital': 'Pasto'}

# %%
for k in range(33):
    print("pays n°", k,":", data['features'][k]['properties']['name'], "capitale n°", k,":", data['features'][k]['properties']['capital'] )
# Out:
# pays n° 0 : Nariño capitale n° 0 : Pasto
# pays n° 1 : Putumayo capitale n° 1 : Mocoa
# pays n° 2 : Chocó capitale n° 2 : Quibdó
# pays n° 3 : Guainía capitale n° 3 : Inírida
# pays n° 4 : Vaupés capitale n° 4 : Mitú
# pays n° 5 : Amazonas capitale n° 5 : Leticia
# pays n° 6 : La Guajira capitale n° 6 : Riohacha
# pays n° 7 : Cesar capitale n° 7 : Valledupar
# pays n° 8 : Norte de Santander capitale n° 8 : Cúcuta
# pays n° 9 : Arauca capitale n° 9 : Arauca
# pays n° 10 : Boyacá capitale n° 10 : Tunja
# pays n° 11 : Vichada capitale n° 11 : Puerto Carreño
# pays n° 12 : Cauca capitale n° 12 : Popayán
# pays n° 13 : Valle del Cauca capitale n° 13 : Cali
# pays n° 14 : Antioquia capitale n° 14 : Medellín
# pays n° 15 : Córdoba capitale n° 15 : Montería
# pays n° 16 : Sucre capitale n° 16 : Sincelejo
# pays n° 17 : Bolívar capitale n° 17 : Cartagena de Indias
# pays n° 18 : Atlántico capitale n° 18 : Barranquilla
# pays n° 19 : Magdalena capitale n° 19 : Santa Marta
# ...
